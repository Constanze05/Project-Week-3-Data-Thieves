# %%
import requests
import json
import pandas as pd
from requests.auth import HTTPBasicAuth
from getpass import getpass
import numpy as np

# %%
airport = pd.read_csv('airportdata_public2.csv')
#airport = airport.head(60)
airport.columns
# Out:
# Index(['IATA', 'Airport', 'Location', 'Area', 'Passenger Role', '2010', '2011',
#        '2012', '2013', '2014', '2015', '2016', '2017'],
#       dtype='object')

# %%
airport
# Out:
#      IATA                          Airport    Location          Area  \
# 0     AAC   El Arish International Airport    El Arish  north_africa
# 1     AAE              Rabah Bitat Airport      Annaba  north_africa
# 2     AAL                  Aalborg Airport     Aalborg       nordics
# 3     AAN     Al Ain International Airport      Al Ain   middle_east
# 4     AAQ                    Anapa Airport       Anapa        russia
# ...   ...                              ...         ...           ...
# 1253  ZQN               Queenstown Airport  Queenstown       oceania
# 1254  ZRH                   Zurich Airport      Zurich   switzerland
# 1255  ZTH  Zakynthos International Airport   Zakynthos        greece
# 1256  ZUH            Zhuhai Jinwan Airport      Zhuhai     east_asia
# 1257  ZYL     Osmani International Airport      Sylhet    south_asia
#
#      Passenger Role  2010  2011  2012  2013  2014        2015  2016       2017
# ...

# %%
airports = airport[['IATA','Airport','Location','Area','Passenger Role']]

# %%
airports
# Out:
#      IATA                          Airport    Location          Area  \
# 0     AAC   El Arish International Airport    El Arish  north_africa
# 1     AAE              Rabah Bitat Airport      Annaba  north_africa
# 2     AAL                  Aalborg Airport     Aalborg       nordics
# 3     AAN     Al Ain International Airport      Al Ain   middle_east
# 4     AAQ                    Anapa Airport       Anapa        russia
# ...   ...                              ...         ...           ...
# 1253  ZQN               Queenstown Airport  Queenstown       oceania
# 1254  ZRH                   Zurich Airport      Zurich   switzerland
# 1255  ZTH  Zakynthos International Airport   Zakynthos        greece
# 1256  ZUH            Zhuhai Jinwan Airport      Zhuhai     east_asia
# 1257  ZYL     Osmani International Airport      Sylhet    south_asia
#
#      Passenger Role
# 0           Non-Hub
# 1           Non-Hub
# 2             Small
# 3           Non-Hub
# 4             Small
# ...

# %%
routes = pd.read_csv('routes.csv')
routes.head(20)
# Out:
#    airline airline ID  source airport  source airport id  \
# 0       2B        410             AER               2965
# 1       2B        410             ASF               2966
# 2       2B        410             ASF               2966
# 3       2B        410             CEK               2968
# 4       2B        410             CEK               2968
# 5       2B        410             DME               4029
# 6       2B        410             DME               4029
# 7       2B        410             DME               4029
# 8       2B        410             DME               4029
# 9       2B        410             EGO               6156
# 10      2B        410             EGO               6156
# 11      2B        410             GYD               2922
# 12      2B        410             KGD               2952
# 13      2B        410             KZN               2990
# 14      2B        410             KZN               2990
# ...

# %%
test = airports[['IATA','Airport']]
test
# Out:
#      IATA                          Airport
# 0     AAC   El Arish International Airport
# 1     AAE              Rabah Bitat Airport
# 2     AAL                  Aalborg Airport
# 3     AAN     Al Ain International Airport
# 4     AAQ                    Anapa Airport
# ...   ...                              ...
# 1253  ZQN               Queenstown Airport
# 1254  ZRH                   Zurich Airport
# 1255  ZTH  Zakynthos International Airport
# 1256  ZUH            Zhuhai Jinwan Airport
# 1257  ZYL     Osmani International Airport
#
# [1258 rows x 2 columns]

# %%
airport_dict = dict(zip(airports.IATA,airports.Airport))
airport_dict
# Out:
# {'AAC': 'El Arish International Airport',
#  'AAE': 'Rabah Bitat Airport',
#  'AAL': 'Aalborg Airport',
#  'AAN': 'Al Ain International Airport',
#  'AAQ': 'Anapa Airport',
#  'AAR': 'Aarhus Airport',
#  'ABA': 'Abakan International Airport',
#  'ABB': 'Asaba International Airport',
#  'ABJ': 'Port Bouet Airport',
#  'ABQ': 'Albuquerque International Sunport',
#  'ABV': 'Nnamdi Azikiwe International Airport',
#  'ABZ': 'Aberdeen Airport',
#  'ACA': 'General Juan N. Alvarez International Airport',
#  'ACC': 'Kotoka International Airport',
#  'ACE': 'Lanzarote Airport',
#  'ACH': 'St. Gallen-Altenrhein Airport',
#  'ACY': 'Atlantic City International Airport',
#  'ADA': 'Şakirpaşa Airport',
#  'ADB': 'Adnan Menderes Airport',
#  'ADD': 'Addis Ababa Bole International Airport',
#  'ADE': 'Aden International Airport',
#  'ADJ': 'Amman Civil Airport',
#  'ADL': 'Adelaide Airport',
#  'ADZ': 'Gustavo Rojas Pinilla International Airport',
#  'AEP': 'Aeroparque Jorge Newbery',
# ...

# %%
routes = routes.replace({" source airport": airport_dict}).replace({" destination apirport": airport_dict})
routes
# Out:
#       airline airline ID                    source airport  source airport id  \
# 0          2B        410       Sochi International Airport               2965
# 1          2B        410                Narimanovo Airport               2966
# 2          2B        410                Narimanovo Airport               2966
# 3          2B        410               Chelyabinsk Airport               2968
# 4          2B        410               Chelyabinsk Airport               2968
# ...       ...        ...                               ...                ...
# 67658      ZL       4178                               WYA               6334
# 67659      ZM      19016  Domodedovo International Airport               4029
# 67660      ZM      19016                     Manas Airport               2912
# 67661      ZM      19016                     Manas Airport               2912
# 67662      ZM      19016                       Osh Airport               2913
#
# ...

# %%
#routes["source airport"].replace(airport_dict, inplace=True)

# %%
routes.columns
# Out:
# Index(['airline', 'airline ID', ' source airport', ' source airport id',
#        ' destination apirport', ' destination airport id', ' codeshare',
#        ' stops', ' equipment'],
#       dtype='object')

# %%
location_dict = dict(zip(airports.Airport,airports.Location))
location_dict
# Out:
# {'El Arish International Airport': 'El Arish',
#  'Rabah Bitat Airport': 'Annaba',
#  'Aalborg Airport': 'Aalborg',
#  'Al Ain International Airport': 'Al Ain',
#  'Anapa Airport': 'Anapa',
#  'Aarhus Airport': 'Aarhus',
#  'Abakan International Airport': 'Abakan',
#  'Asaba International Airport': 'Asaba, Delta',
#  'Port Bouet Airport': 'Abidjan',
#  'Albuquerque International Sunport': 'Albuquerque',
#  'Nnamdi Azikiwe International Airport': 'Abuja',
#  'Aberdeen Airport': 'Aberdeen',
#  'General Juan N. Alvarez International Airport': 'Acapulco',
#  'Kotoka International Airport': 'Accra',
#  'Lanzarote Airport': 'Lanzarote',
#  'St. Gallen-Altenrhein Airport': 'St. Gallen',
#  'Atlantic City International Airport': 'Atlantic City',
#  'Şakirpaşa Airport': 'Adana',
#  'Adnan Menderes Airport': 'İzmir',
#  'Addis Ababa Bole International Airport': 'Addis Ababa',
#  'Aden International Airport': 'Aden',
#  'Amman Civil Airport': 'Amman',
#  'Adelaide Airport': 'Adelaide',
# ...

# %%
area_dict = dict(zip(airports.Airport,airports.Area))
area_dict
# Out:
# {'El Arish International Airport': 'north_africa',
#  'Rabah Bitat Airport': 'north_africa',
#  'Aalborg Airport': 'nordics',
#  'Al Ain International Airport': 'middle_east',
#  'Anapa Airport': 'russia',
#  'Aarhus Airport': 'nordics',
#  'Abakan International Airport': 'russia',
#  'Asaba International Airport': 'west_africa',
#  'Port Bouet Airport': 'west_africa',
#  'Albuquerque International Sunport': 'united_states',
#  'Nnamdi Azikiwe International Airport': 'west_africa',
#  'Aberdeen Airport': 'united_kingdom',
#  'General Juan N. Alvarez International Airport': 'north_america',
#  'Kotoka International Airport': 'west_africa',
#  'Lanzarote Airport': 'spain',
#  'St. Gallen-Altenrhein Airport': 'switzerland',
#  'Atlantic City International Airport': 'united_states',
#  'Şakirpaşa Airport': 'europe_misc',
#  'Adnan Menderes Airport': 'europe_misc',
#  'Addis Ababa Bole International Airport': 'horn_of_africa',
#  'Aden International Airport': 'middle_east',
# ...

# %%
passenger_dict = dict(zip(airports["Airport"],airports["Passenger Role"]))
passenger_dict
# Out:
# {'El Arish International Airport': 'Non-Hub',
#  'Rabah Bitat Airport': 'Non-Hub',
#  'Aalborg Airport': 'Small',
#  'Al Ain International Airport': 'Non-Hub',
#  'Anapa Airport': 'Small',
#  'Aarhus Airport': 'Non-Hub',
#  'Abakan International Airport': 'Non-Hub',
#  'Asaba International Airport': 'Non-Hub',
#  'Port Bouet Airport': 'Non-Hub',
#  'Albuquerque International Sunport': 'Medium',
#  'Nnamdi Azikiwe International Airport': 'Medium',
#  'Aberdeen Airport': 'Medium',
#  'General Juan N. Alvarez International Airport': 'Small',
#  'Kotoka International Airport': 'Small',
#  'Lanzarote Airport': 'Medium',
#  'St. Gallen-Altenrhein Airport': 'Non-Hub',
#  'Atlantic City International Airport': 'Small',
#  'Şakirpaşa Airport': 'Non-Hub',
#  'Adnan Menderes Airport': 'Non-Hub',
#  'Addis Ababa Bole International Airport': 'Non-Hub',
#  'Aden International Airport': 'Non-Hub',
#  'Amman Civil Airport': 'Non-Hub',
#  'Adelaide Airport': 'Medium',
# ...

# %%
location_dict = dict(zip(airports.Airport,airports.Location))

routes['location'] = routes[' source airport'].map(location_dict)
routes
# Out:
#       airline airline ID                    source airport  source airport id  \
# 0          2B        410       Sochi International Airport               2965
# 1          2B        410                Narimanovo Airport               2966
# 2          2B        410                Narimanovo Airport               2966
# 3          2B        410               Chelyabinsk Airport               2968
# 4          2B        410               Chelyabinsk Airport               2968
# ...       ...        ...                               ...                ...
# 67658      ZL       4178                               WYA               6334
# 67659      ZM      19016  Domodedovo International Airport               4029
# 67660      ZM      19016                     Manas Airport               2912
# 67661      ZM      19016                     Manas Airport               2912
# 67662      ZM      19016                       Osh Airport               2913
#
# ...
